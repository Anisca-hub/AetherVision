# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/AetherVision
# Out:
# /content/drive/MyDrive/AetherVision

# %%
# !ls -F
# Out:
# data/  main.py	notebooks/  README.md  requirements.txt  src/

# %%
# Force-install compatible versions
# !pip install numpy==1.26.4 scikit-learn==1.4.2 torch==2.2.0 torchvision==0.17.0 lightning==2.1.0 --force-reinstall

# Important: Clear the output and verify
from IPython.display import clear_output
clear_output()
print("Environment cleaned. Ready to run.")
# Out:
# Environment cleaned. Ready to run.

# %%
# %cd /content/drive/MyDrive/AetherVision
# !python main.py
# Out:
# /content/drive/MyDrive/AetherVision
# Data directory verified at ./data/raw
# DEBUG: Successfully loaded 2600 images from ./data/raw/train_dataset/train.json.
# ...
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Training started...
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/configuration_validator.py:72: You passed in a `val_dataloader` but have no `validation_step`. Skipping val loop.
# 2026-06-04 15:36:07.100996: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type              | Params
# ------------------------------------------------
# ...

# %%
# !ls -F
# Out:
# data/		 main.py    notebooks/	requirements.txt
# lightning_logs/  model.pth  README.md	src/

# %%
# !find /content/drive -name "exploration.ipynb"
# Out:
# /content/drive/MyDrive/AetherVision/notebooks/exploration.ipynb

# %%
import sys
import os

# Fix 1: Add project root to path so 'src' can be found
project_path = '/content/drive/MyDrive/AetherVision'
sys.path.append(project_path)
os.chdir(project_path) # Move to the project root

# Fix 2: Check the data directory
print("Current directory:", os.getcwd())
print("Does data exist?", os.path.exists("./data/raw"))
# Out:
# Current directory: /content/drive/MyDrive/AetherVision
# Does data exist? True
